# %% [markdown]
# # DATA 271 Practice Midterm 2

# %% [markdown]
# We will begin with some basic practice problems.

# %% [markdown]
# **Practice 1:** List all components of a data visualization according to the Grammar of Graphics.

# %% [markdown]
# - data
# - aesthetic mapping
# - scales
# - geometric objects
# - facets
# - statistical transformations
# - coordinate system

# %% [markdown]
# **Practice 2:** True or False: Plotnine is the only data visualization module in Python that can be
# used to create figures that have Grammar of Graphics components. Enter True or False.

# %%
False
# Out:
# False

# %% [markdown]
# **Practice 3:** Which visualization technique is best suited for displaying outliers of
# data?
#
# 1. Box plot
# 2. Swarm plot
# 3. Heatmap
# 4. Violin plot
#
# Enter 1, 2, 3, or 4.

# %%
best_vis = 1

# %% [markdown]
# **Practice 4:** Rearrange the table below so that each plot is matched with its common use :
#
# | Chart type   | Use                                              |
# | :----------- | :----------------------------------------------- |
# | Bar chart    | Show trends over time                            |
# | Line graph   | Visualizing matrix-like data (e.g. correlations) |
# | Heatmap      | Show relationships between variables             |
# | Scatter plot | Compare values in categories                     |
# | Violin plot  | Show numerical distributions                     |
# | Histogram    | Smooth distribtions and quartiles                |

# %% [markdown]
# Rearrange here:
# | Chart type   | Use                                              |
# | :----------- | :----------------------------------------------- |
# | Bar chart    | Compare values in categories                          |
# | Line graph   |Show trends over time  |
# | Heatmap      |  Visualizing matrix-like data (e.g. correlations)             |
# | Scatter plot | Show relationships between variables                     |
# | Violin plot  | Smooth distribtions and quartiles                    |
# | Histogram    | Show numerical distributions                 |

# %% [markdown]
# **Practice 5** For the following figures, describe what is not good about the data visualization according
# to the principles of data visualization. How you would improve it?
#
#  ![graph](bad_viz.png)
#  ![graph](bad_viz2.png)
#  ![graph](bad_viz3.png)

# %% [markdown]
# (note, these are just possible answers)
#
# *Graph 1*
# - Good: Informative title, easy to read tick labels
# - Bad: Way too busy with unnecessary stick figures. Unnecessary use of colors. Scale of y-axis is misleading
# - Suggestion: Make this a standard bar chart with one color. Change the y-axis scale to start at 0.
#
# *Graph 2*
# - Good: Clean simple figure
# - Bad: Title is difficult to understand without context, y-axis isn't labeled. Scale of y-axis is misleading
# - Suggestion: Generally provide more context (better title and axis labels). Change the y-axis scale to start at 0.
#
# *Graph 3*
# - Good: Title is descriptive enough. Good use of color to show multiple variables.
# - Bad: axes should be labeled to provide necessary context. Plot type is not the best. The format of the dates is odd. Too busy with each number listed individually.
# - Suggestions: change the date format (e.g. Pandas datetime), change the plot type (line). Remove individual numebers. Consider facetting instead of using colors (depends on goals).

# %% [markdown]
# **Practice 6:** The [Rick and Morty API](https://rickandmortyapi.com) has
# three possible endpoints: character, location, or episode. The character endpoint has several optional parameters. One of them is name which takes the first name of the character in the show. What would Python code would you use to get information about Rick in the Rick and Morty API.

# %%
import requests
response = requests.get('https://rickandmortyapi.com/api/character/')
response.status_code
# Note, you could have gotten this another way
# Out:
# 200

# %%
response.json()['results'][0]
# Out:
# {'id': 1,
#  'name': 'Rick Sanchez',
#  'status': 'Alive',
#  'species': 'Human',
#  'type': '',
#  'gender': 'Male',
#  'origin': {'name': 'Earth (C-137)',
#   'url': 'https://rickandmortyapi.com/api/location/1'},
#  'location': {'name': 'Citadel of Ricks',
#   'url': 'https://rickandmortyapi.com/api/location/3'},
#  'image': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg',
#  'episode': ['https://rickandmortyapi.com/api/episode/1',
#   'https://rickandmortyapi.com/api/episode/2',
#   'https://rickandmortyapi.com/api/episode/3',
#   'https://rickandmortyapi.com/api/episode/4',
#   'https://rickandmortyapi.com/api/episode/5',
#   'https://rickandmortyapi.com/api/episode/6',
#   'https://rickandmortyapi.com/api/episode/7',
#   'https://rickandmortyapi.com/api/episode/8',
#   'https://rickandmortyapi.com/api/episode/9',
#   'https://rickandmortyapi.com/api/episode/10',
#   'https://rickandmortyapi.com/api/episode/11',
#   'https://rickandmortyapi.com/api/episode/12',
#   'https://rickandmortyapi.com/api/episode/13',
#   'https://rickandmortyapi.com/api/episode/14',
#   'https://rickandmortyapi.com/api/episode/15',
#   'https://rickandmortyapi.com/api/episode/16',
#   'https://rickandmortyapi.com/api/episode/17',
#   'https://rickandmortyapi.com/api/episode/18',
#   'https://rickandmortyapi.com/api/episode/19',
#   'https://rickandmortyapi.com/api/episode/20',
#   'https://rickandmortyapi.com/api/episode/21',
#   'https://rickandmortyapi.com/api/episode/22',
#   'https://rickandmortyapi.com/api/episode/23',
#   'https://rickandmortyapi.com/api/episode/24',
#   'https://rickandmortyapi.com/api/episode/25',
#   'https://rickandmortyapi.com/api/episode/26',
#   'https://rickandmortyapi.com/api/episode/27',
#   'https://rickandmortyapi.com/api/episode/28',
#   'https://rickandmortyapi.com/api/episode/29',
#   'https://rickandmortyapi.com/api/episode/30',
#   'https://rickandmortyapi.com/api/episode/31',
#   'https://rickandmortyapi.com/api/episode/32',
#   'https://rickandmortyapi.com/api/episode/33',
#   'https://rickandmortyapi.com/api/episode/34',
#   'https://rickandmortyapi.com/api/episode/35',
#   'https://rickandmortyapi.com/api/episode/36',
#   'https://rickandmortyapi.com/api/episode/37',
#   'https://rickandmortyapi.com/api/episode/38',
#   'https://rickandmortyapi.com/api/episode/39',
#   'https://rickandmortyapi.com/api/episode/40',
#   'https://rickandmortyapi.com/api/episode/41',
#   'https://rickandmortyapi.com/api/episode/42',
#   'https://rickandmortyapi.com/api/episode/43',
#   'https://rickandmortyapi.com/api/episode/44',
#   'https://rickandmortyapi.com/api/episode/45',
#   'https://rickandmortyapi.com/api/episode/46',
#   'https://rickandmortyapi.com/api/episode/47',
#   'https://rickandmortyapi.com/api/episode/48',
#   'https://rickandmortyapi.com/api/episode/49',
#   'https://rickandmortyapi.com/api/episode/50',
#   'https://rickandmortyapi.com/api/episode/51'],
#  'url': 'https://rickandmortyapi.com/api/character/1',
#  'created': '2017-11-04T18:48:46.250Z'}

# %%
rick_response = requests.get('https://rickandmortyapi.com/api/character/1')
rick_response.json()
# Out:
# {'id': 1,
#  'name': 'Rick Sanchez',
#  'status': 'Alive',
#  'species': 'Human',
#  'type': '',
#  'gender': 'Male',
#  'origin': {'name': 'Earth (C-137)',
#   'url': 'https://rickandmortyapi.com/api/location/1'},
#  'location': {'name': 'Citadel of Ricks',
#   'url': 'https://rickandmortyapi.com/api/location/3'},
#  'image': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg',
#  'episode': ['https://rickandmortyapi.com/api/episode/1',
#   'https://rickandmortyapi.com/api/episode/2',
#   'https://rickandmortyapi.com/api/episode/3',
#   'https://rickandmortyapi.com/api/episode/4',
#   'https://rickandmortyapi.com/api/episode/5',
#   'https://rickandmortyapi.com/api/episode/6',
#   'https://rickandmortyapi.com/api/episode/7',
#   'https://rickandmortyapi.com/api/episode/8',
#   'https://rickandmortyapi.com/api/episode/9',
#   'https://rickandmortyapi.com/api/episode/10',
#   'https://rickandmortyapi.com/api/episode/11',
#   'https://rickandmortyapi.com/api/episode/12',
#   'https://rickandmortyapi.com/api/episode/13',
#   'https://rickandmortyapi.com/api/episode/14',
#   'https://rickandmortyapi.com/api/episode/15',
#   'https://rickandmortyapi.com/api/episode/16',
#   'https://rickandmortyapi.com/api/episode/17',
#   'https://rickandmortyapi.com/api/episode/18',
#   'https://rickandmortyapi.com/api/episode/19',
#   'https://rickandmortyapi.com/api/episode/20',
#   'https://rickandmortyapi.com/api/episode/21',
#   'https://rickandmortyapi.com/api/episode/22',
#   'https://rickandmortyapi.com/api/episode/23',
#   'https://rickandmortyapi.com/api/episode/24',
#   'https://rickandmortyapi.com/api/episode/25',
#   'https://rickandmortyapi.com/api/episode/26',
#   'https://rickandmortyapi.com/api/episode/27',
#   'https://rickandmortyapi.com/api/episode/28',
#   'https://rickandmortyapi.com/api/episode/29',
#   'https://rickandmortyapi.com/api/episode/30',
#   'https://rickandmortyapi.com/api/episode/31',
#   'https://rickandmortyapi.com/api/episode/32',
#   'https://rickandmortyapi.com/api/episode/33',
#   'https://rickandmortyapi.com/api/episode/34',
#   'https://rickandmortyapi.com/api/episode/35',
#   'https://rickandmortyapi.com/api/episode/36',
#   'https://rickandmortyapi.com/api/episode/37',
#   'https://rickandmortyapi.com/api/episode/38',
#   'https://rickandmortyapi.com/api/episode/39',
#   'https://rickandmortyapi.com/api/episode/40',
#   'https://rickandmortyapi.com/api/episode/41',
#   'https://rickandmortyapi.com/api/episode/42',
#   'https://rickandmortyapi.com/api/episode/43',
#   'https://rickandmortyapi.com/api/episode/44',
#   'https://rickandmortyapi.com/api/episode/45',
#   'https://rickandmortyapi.com/api/episode/46',
#   'https://rickandmortyapi.com/api/episode/47',
#   'https://rickandmortyapi.com/api/episode/48',
#   'https://rickandmortyapi.com/api/episode/49',
#   'https://rickandmortyapi.com/api/episode/50',
#   'https://rickandmortyapi.com/api/episode/51'],
#  'url': 'https://rickandmortyapi.com/api/character/1',
#  'created': '2017-11-04T18:48:46.250Z'}

# %% [markdown]
# **Practice 7:** Given the diamonds dataset in seaborn, I created the following visualisation.
# ![diamonds](diamonds_plot.png)
# Write the code to recreate this figure.

# %%
import seaborn as sns
diamonds = sns.load_dataset('diamonds')

sns.catplot(data = diamonds, x = 'color',y='price', col = 'cut', kind='bar')
# Out:
# /Users/bj117/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Practice 8:** You are working with the following Pandas dataframe `pets`. You want to clean it up a
# little and add some columns.

# %%
# Create a cute pets DataFrame
import pandas as pd
data = {
    'Pet Name': ['Fluffy', 'Whiskers', 'Bubbles', 'Spike', 'Coco'],
    'Animal Type': ['Cat', 'Rabbit', 'Fish', 'Dog', 'Hamster'],
    'Age': [3, 2, 1, 5, 4],
    'Color': ['White', 'Gray', 'Orange', 'Brown', 'Golden'],
    'Happiness Score': [9.5, 8.0, 9.2, 7.3, 9.8]
}
pets = pd.DataFrame(data)
pets
# Out:
#    Pet Name Animal Type  Age   Color  Happiness Score
# 0    Fluffy         Cat    3   White              9.5
# 1  Whiskers      Rabbit    2    Gray              8.0
# 2   Bubbles        Fish    1  Orange              9.2
# 3     Spike         Dog    5   Brown              7.3
# 4      Coco     Hamster    4  Golden              9.8

# %% [markdown]
# The following code has errors in it. Find the errors and correct them.

# %%
# Add column called Mine full of False
pets['Mine'] = False
pets.head(2)
# Out:
#    Pet Name Animal Type  Age  Color  Happiness Score   Mine
# 0    Fluffy         Cat    3  White              9.5  False
# 1  Whiskers      Rabbit    2   Gray              8.0  False

# %%
# Rename the columns so there are no spaces
pets.columns = pets.columns.str.replace(' ', '_')
pets.head(2)
# Out:
#    Pet_Name Animal_Type  Age  Color  Happiness_Score   Mine
# 0    Fluffy         Cat    3  White              9.5  False
# 1  Whiskers      Rabbit    2   Gray              8.0  False

# %%
# Reset the index as Pet Name
pets.set_index('Pet_Name')
# Out:
#          Animal_Type  Age   Color  Happiness_Score   Mine
# Pet_Name
# Fluffy           Cat    3   White              9.5  False
# Whiskers      Rabbit    2    Gray              8.0  False
# Bubbles         Fish    1  Orange              9.2  False
# Spike            Dog    5   Brown              7.3  False
# Coco         Hamster    4  Golden              9.8  False

# %% [markdown]
# In the next section of this practice midterm, we will perform an exploratory data analysis on a rollercoaster dataset. Follow the steps below to perform your EDA.
#
# The actual midterm will also involve an exploratory data analysis.

# %% [markdown]
# **Problem 0:** Import the required modules for this EDA. You will need, Numpy, Pandas, Matplotlib, Seaborn, and re. Feel free to use this cell to set the style and/or runtime configuration parameters for your Seaborn plots if you want to.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## 1. Import the data and begin exploration

# %% [markdown]
# **Problem 1.1:** Import the `rollercoasters.csv` file (already in your working directory) as a Pandas DataFrame.

# %%
df = pd.read_csv('rollercoasters.csv')
df.head()
# Out:
#                              coaster_name  ... Opening Date
# 0                      Switchback Railway  ...   1884-06-16
# 1                       Flip Flap Railway  ...   1895-01-01
# 2  Switchback Railway (Euclid Beach Park)  ...          NaN
# 3            Loop the Loop (Coney Island)  ...   1901-01-01
# 4            Loop the Loop (Young's Pier)  ...   1901-01-01
#
# [5 rows x 43 columns]

# %% [markdown]
# **Problem 1.2:** How many rows and columns are in your dataframe?

# %%
num_rows = df.shape[0]
num_cols = df.shape[1]
num_rows, num_cols
# Out:
# (1087, 43)

# %% [markdown]
# **Problem 1.3**: Begin with an initial inspection of your dataframe. What are the column names? How many null values are in each column? What is the datatype of each column?
#
# *HINT* Feel free to use a single Pandas method get this information, or use several if you prefer that.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 43 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Type                           1087 non-null   object
#  6   Manufacturer                   1028 non-null   object
#  7   Model                          744 non-null    object
#  8   Height                         965 non-null    object
#  9   Inversions                     932 non-null    float64
#  10  Lift/launch system             795 non-null    object
#  11  Cost                           382 non-null    object
#  12  Trains                         718 non-null    object
#  13  Park section                   487 non-null    object
#  14  Duration                       765 non-null    object
#  15  Capacity                       575 non-null    object
#  16  G-force                        362 non-null    object
#  17  Designer                       578 non-null    object
#  18  Max vertical angle             357 non-null    object
#  19  Drop                           494 non-null    object
#  20  Soft opening date              96 non-null     object
#  21  Fast Lane available            69 non-null     object
#  22  Replaced                       173 non-null    object
#  23  Track layout                   335 non-null    object
#  24  Fastrack available             19 non-null     object
#  25  Soft opening date.1            96 non-null     object
#  26  Closing date                   236 non-null    object
#  27  Opened                         27 non-null     object
#  28  Replaced by                    88 non-null     object
#  29  Website                        87 non-null     object
#  30  Flash Pass Available           50 non-null     object
#  31  Must transfer from wheelchair  106 non-null    object
#  32  Theme                          44 non-null     object
#  33  Single rider line available    81 non-null     object
#  34  Restraint Style                22 non-null     object
#  35  Flash Pass available           46 non-null     object
#  36  Acceleration                   60 non-null     object
#  37  Restraints                     24 non-null     object
#  38  year_introduced                1087 non-null   int64
#  39  latitude                       812 non-null    float64
#  40  longitude                      812 non-null    float64
#  41  Type_Main                      1087 non-null   object
#  42  Opening Date                   837 non-null    object
# dtypes: float64(3), int64(1), object(39)
# memory usage: 365.3+ KB

# %% [markdown]
# ## 2. Begin Data Cleaning

# %% [markdown]
# **Problem 2.1**: The current column names are not in a standardized format. Rename the columns so they are all in the form `lowercase_with_underscores`.
#
# *HINT:* When you are done, there should not be any special characters such as dashes or slashes.

# %%
df.columns = ['_'.join(i.split()).lower() for i in df.columns]
df.head()
# Out:
#                              coaster_name  ... opening_date
# 0                      Switchback Railway  ...   1884-06-16
# 1                       Flip Flap Railway  ...   1895-01-01
# 2  Switchback Railway (Euclid Beach Park)  ...          NaN
# 3            Loop the Loop (Coney Island)  ...   1901-01-01
# 4            Loop the Loop (Young's Pier)  ...   1901-01-01
#
# [5 rows x 43 columns]

# %% [markdown]
# **Problem 2.2:** Create a copy of your dataframe called `df_copy`, so that the original data will be accessible even after we make changes.

# %%
df_copy = df.copy()

# %% [markdown]
# **Problem 2.3:** Some columns have many null values. Drop all the columns from the dataframe `df` that have more than 250 null values.

# %%
df = df.loc[:,df.isna().sum() <= 250]

# %% [markdown]
# **Problem 2.4** How many columns are left in the dataframe after dropping the columns with more than 250 null values?

# %%
new_num_cols = df.shape[1]
new_num_cols
# Out:
# 12

# %% [markdown]
# **Problem 2.5** Visualize the number of null values in each column with a heatmap.

# %%
sns.heatmap(df.isna());

# %% [markdown]
# **Problem 2.6** Inpsect the `height` column of the dataset. We want to extract the height in feet (ft) from the column. Create a new column called `height_ft` in your `df` DataFrame containing the heights in feet. Do not convert any data types; leave them as strings.
#
# *HINT:* You may want to use regular expression for this problem. Note that some of the heights are shown in whole numbers and some of them include digits past a decimal. Be sure to include decimals if they are available. Any NaNs should remain NaN in your new column.

# %%
# inspect height column
df.height
# Out:
# 0           50 ft (15 m)
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#               ...
# 1082       111 ft (34 m)
# 1083       178 ft (54 m)
# 1084    78.1 ft (23.8 m)
# 1085       112 ft (34 m)
# 1086       131 ft (40 m)
# Name: height, Length: 1087, dtype: object

# %%
df['height_ft'] = df.height.str.extract('([\d.]+)\s*ft')
df.head()
# Out:
#                              coaster_name  ... height_ft
# 0                      Switchback Railway  ...        50
# 1                       Flip Flap Railway  ...       NaN
# 2  Switchback Railway (Euclid Beach Park)  ...       NaN
# 3            Loop the Loop (Coney Island)  ...       NaN
# 4            Loop the Loop (Young's Pier)  ...       NaN
#
# [5 rows x 13 columns]

# %% [markdown]
# **Problem 2.7** Inpsect the `speed` column of the dataset. We want to extract the speed in miles per hour (mph) from the column. Create a new column called `speed_mph` in your `df` DataFrame containing the speed in miles per hour. Do not convert any data types; leave them as strings.
#
# HINT: You may want to use regular expression for this problem.

# %%
df.speed
# Out:
# 0              6 mph (9.7 km/h)
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#                  ...
# 1082           53 mph (85 km/h)
# 1083          73 mph (117 km/h)
# 1084    59.3[1] mph (95.4 km/h)
# 1085           34 mph (55 km/h)
# 1086           58 mph (93 km/h)
# Name: speed, Length: 1087, dtype: object

# %%
df['speed_mph'] = df.speed.str.extract('([\d.]+).*mph')
df.tail()
# Out:
#                         coaster_name                length  ... height_ft speed_mph
# 1082         American Dreier Looping    3,444 ft (1,050 m)  ...       111        53
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)  ...       178        73
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)  ...      78.1      59.3
# 1085                         Tumbili        770 ft (230 m)  ...       112        34
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)  ...       131        58
#
# [5 rows x 14 columns]

# %% [markdown]
# **Problem 2.8** Inpsect the `length` column of the dataset. We want to extract the length in feet (ft_ from the column. Create a new column called `length_ft` in your `df` DataFrame containing the length in feet. Do not convert any data types; leave them as strings.
#
# HINT: You may want to use regular expression for this problem. Note that some of the lengths include a comma. You will need to account for that in your regular expression, but do not include the comma in your final `length_ft` column.

# %%
df.length
# Out:
# 0             600 ft (180 m)
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#                 ...
# 1082      3,444 ft (1,050 m)
# 1083      3,328 ft (1,014 m)
# 1084    3,169.3 ft (966.0 m)
# 1085          770 ft (230 m)
# 1086      3,300 ft (1,000 m)
# Name: length, Length: 1087, dtype: object

# %%
df['length_ft'] = df.length.str.extract('([\d,]+).*ft')
df.head()
# Out:
#                              coaster_name          length  ... speed_mph length_ft
# 0                      Switchback Railway  600 ft (180 m)  ...         6       600
# 1                       Flip Flap Railway             NaN  ...       NaN       NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN  ...       NaN       NaN
# 3            Loop the Loop (Coney Island)             NaN  ...       NaN       NaN
# 4            Loop the Loop (Young's Pier)             NaN  ...       NaN       NaN
#
# [5 rows x 15 columns]

# %% [markdown]
# **Problem 2.9** Are there any duplicates in the `coaster_name` column? If there are, remove any rows that have a duplicate `coaster_name` column.

# %%
num_duplicate_coasters = df.coaster_name.duplicated().sum()
num_duplicate_coasters
# Out:
# 97

# %%
# drop duplicate coaster names
df.drop_duplicates(subset='coaster_name',inplace=True)

# %% [markdown]
# **Problem 2.10** Use a Pandas method to get summary statistics for each numeric variable in the dataset.

# %%
df.describe()
# Out:
#        inversions  year_introduced
# count  843.000000       990.000000
# mean     1.536180      1994.054545
# std      2.115334        23.872027
# min      0.000000      1884.000000
# 25%      0.000000      1988.000000
# 50%      0.000000      2000.000000
# 75%      3.000000      2009.000000
# max     14.000000      2022.000000

# %% [markdown]
# ## 3. Visualize

# %% [markdown]
# **Problem 3.1** In the following three cells, there is a problem with the data visualizations identify what the problems are and make the necessary changes to the data to get the proper plots.

# %%
# Visualize the relationship between length and height of rollercoasters
sns.scatterplot(data = df, x = 'length_ft',y='height_ft')
plt.show()

# %%
# Visualize the relationship between speed and height of rollercoasters and their distributions
sns.jointplot(data = df, x = 'speed_mph',y='height_ft')
plt.show()

# %%
# Visualize the trend in speed of rollercoasters over time
sns.lineplot(data = df, x = 'opening_date',y = 'speed_mph')
plt.show()

# %%
# Make necessary changes here
df.length_ft = df.length_ft.str.replace(',', '')

df = df.astype({'height_ft':float,
          'length_ft':float,
          'speed_mph':float})
df.head()
# Out:
#                              coaster_name          length  ... speed_mph length_ft
# 0                      Switchback Railway  600 ft (180 m)  ...       6.0     600.0
# 1                       Flip Flap Railway             NaN  ...       NaN       NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN  ...       NaN       NaN
# 3            Loop the Loop (Coney Island)             NaN  ...       NaN       NaN
# 4            Loop the Loop (Young's Pier)             NaN  ...       NaN       NaN
#
# [5 rows x 15 columns]

# %%
# REDO: Visualize the relationship between length and height of rollercoasters
sns.scatterplot(data = df, x = 'length_ft',y='height_ft')
plt.show()

# %%
# REDO: Visualize the relationship between speed and height of rollercoasters and their distributions
sns.jointplot(data = df, x = 'speed_mph',y='height_ft')
plt.show()

# %%
# REDO: Visualize the trend in speed of rollercoasters over time
sns.lineplot(data = df, x = 'opening_date',y = 'speed_mph')
plt.show()

# %% [markdown]
# **Problem 3.2** The plot above showing the trend in speed vs time is a little messy. Let's look at the general relationship instead. Plot the relationship between `speed_mph` and `year_intoduced` (points) and show a regression line. Is it a positive correlation or a negative correlation?

# %%
sns.regplot(data = df, x = 'year_introduced', y = 'speed_mph')
plt.show()

# %% [markdown]
# *Positive correlation. New coasters got faster through time.*

# %% [markdown]
# **Problem 3.3** Plot the correlation between all the numeric variables with a heatmap. (Be sure to annotate your heatmap with the correlation coefficients). Comment on what you see.

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %% [markdown]
# *height and year correlate with speed. (Multiple possible answers).*

# %% [markdown]
# **Problem 3.4:** Visualize the relationship between the numeric variables with a Seaborn pairpplot. Comment on what you see.

# %%
sns.pairplot(data = df)
plt.show()
# Out:
# /Users/bj117/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# *Interesting relationship with height and speed. I wonder why it looks like a V.*

# %% [markdown]
# **Problem 3.5** Visualize the number of rollercoasters of each `type_main`. What is the most common type of rollercoaster?

# %%
sns.countplot(data = df, x ='type_main')
plt.show()

# %% [markdown]
# *Steel coasters are most common in this dataset.*

# %% [markdown]
# **Problem 3.5** Visualize the distribution of rollercoaster speeds (mph).

# %%
sns.histplot(data = df, x ='speed_mph')
plt.show()

# %% [markdown]
# **Problem 3.6:** Visualize the smoothed distribution (KDE) of rollercoaster speeds (mph) for each `type_main` (either map it to color or facet by it). Are there any major differences in speed distributions across rollercoaster type?

# %%
sns.kdeplot(data = df, x = 'speed_mph', hue = 'type_main',fill=True)
plt.show()

# %% [markdown]
# *They interestingly all seem to have a peak around 50mph. I guess the coaster type doesn't correlate with the average speed too much.*

# %% [markdown]
# **Problem 3.7:** Visualize the smoothed distribution of rollercoaster speeds (mph) for each `type_main` AND the 5 number summary (min, 1st quartile, median, 3rd quartile, max).
#
# *HINT:* Which type of plot is a combination of a boxplot and a KDE?

# %%
sns.violinplot(data = df, x = 'type_main',y = 'speed_mph')
plt.show()

# %% [markdown]
# **Problem 3.7:** Create a data visualization to determine if there are any outliers in the numeric variables. Which variables have outliers?

# %%
sns.boxplot(data = df)
plt.show()

# %% [markdown]
# *All the numeric variables have some outliers. (They all have dots).*

# %% [markdown]
# **Problem 3.8** Sort your data frame from fastest rollercoaster to slowest roller coaster. Then create a visualization showing the speed and the rollarcoaster name of the fastest 20 rollercoasters in the dataset.

# %%
df_sorted = df.sort_values(by = 'speed_mph',ascending=False)
df_sorted
# Out:
#                                 coaster_name  ... length_ft
# 812                            Formula Rossa  ...    2000.0
# 569                               Do-Dodonpa  ...    1244.0
# 993               Red Force (roller coaster)  ...     880.0
# 431                       Tower of Terror II  ...     376.0
# 903                               Ring Racer  ...    1212.0
# ...                                      ...  ...       ...
# 1007                         Merlin's Mayhem  ...    1300.0
# 1032            Hurricane (Fun Spot America)  ...       NaN
# 1065             Looping Star (Clacton Pier)  ...     365.0
# 1068            Storm Chaser (Paultons Park)  ...       NaN
# 1078  Guardians of the Galaxy: Cosmic Rewind  ...    5577.0
#
# [990 rows x 15 columns]

# %%
# Visualization here
sns.barplot(data = df_sorted[:20], x='speed_mph', y = 'coaster_name')
plt.show()

# %% [markdown]
# **Problem 3.9:** Use pandas methods and data visualization to show how many rollercoasters were introduced in each year.

# %%
# Pandas methods
df.year_introduced.value_counts()
# Out:
# year_introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
# Visualization
plt.figure(figsize = (6,18))
sns.countplot(data = df, y = 'year_introduced')
plt.show()

# %% [markdown]
# **Problem 3.10:** Create 3 subplots showing the relationships of speed vs year introduced, speed vs height, and speed vs length.

# %%
fig, ax = plt.subplots(1,3,figsize=(12,4))
sns.scatterplot(data = df, x = 'year_introduced',y = 'speed_mph',ax=ax[0],hue='type_main')
sns.scatterplot(data = df, x = 'height_ft',y = 'speed_mph',ax=ax[1],hue='type_main')
sns.scatterplot(data = df, x = 'length_ft',y = 'speed_mph',ax=ax[2],hue='type_main')
plt.tight_layout()

# %% [markdown]
# ## 4. Your exploration

# %% [markdown]
# **Problem 4.1** Create a question about this dataset and use a data visualization to begin answering this question. Explain your thought process.

# %%
# Answers will vary
