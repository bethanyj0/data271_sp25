# %% [markdown]
# # How to Handle Missing Data
# If you want to type along with me, use [this notebook](https://humboldt.cloudbank.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fbethanyj0%2Fdata271_sp24&branch=main&urlpath=tree%2Fdata271_sp24%2Fdemos%2Fdata271_demo35_live.ipynb) instead.
# If you don't want to type and want to follow along just by executing the cells, stay in this notebook.

# %%
import numpy as np
import pandas as pd

# %%
# Import a dataset about Lake Mendocino
df = pd.read_csv('coy_wy2024_csvdata.csv')
df
# Out:
#             ISO 8601 Date Time Top of Conservation High (ac-ft)  \
# 0    2023-08-30T24:00:00-07:00                           111000
# 1    2023-08-31T24:00:00-07:00                           111000
# 2    2023-09-01T24:00:00-07:00                           111000
# 3    2023-09-02T24:00:00-07:00                           111000
# 4    2023-09-03T24:00:00-07:00                           111000
# ..                         ...                              ...
# 235  2024-04-21T24:00:00-07:00                            99930
# 236  2024-04-22T24:00:00-07:00                           100545
# 237  2024-04-23T24:00:00-07:00                           101160
# 238  2024-04-24T24:00:00-07:00                           101775
# 239  2024-04-25T24:00:00-07:00                           102390
#
#      Top of Conservation High (ac-ft) notes Top of Conservation (ac-ft)  \
# 0                                         0                       86400
# 1                                         0                       86400
# 2                                         0                       86400
# 3                                         0                       86400
# 4                                         0                       86400
# ..                                      ...                         ...
# 235                                       0                       86400
# 236                                       0                       86400
# 237                                       0                       86400
# 238                                       0                       86400
# 239                                       0                       86400
#
#      Top of Conservation (ac-ft) notes  Storage (ac-ft)  \
# 0                                    0            84192
# 1                                    0            83966
# 2                                    0            83723
# 3                                    0            83480
# 4                                    0            83271
# ..                                 ...              ...
# 235                                  0           100431
# 236                                  0           100449
# 237                                  0           100467
# 238                                  0           100485
# 239                                  0           100503
#
#      Storage (ac-ft) notes  Elevation (ft-NGVD29)  \
# 0                        0                 746.75
# 1                        0                 746.62
# 2                        0                 746.48
# 3                        0                 746.34
# 4                        0                 746.22
# ..                     ...                    ...
# 235                      0                 755.96
# 236                      0                 755.97
# 237                      0                 755.98
# 238                      0                 755.99
# 239                      0                 756.00
#
#      Elevation (ft-NGVD29) notes  Inflow (cfs)  ...  \
# 0                              0         80.54  ...
# 1                              0         92.30  ...
# 2                              0         74.82  ...
# 3                              0         76.72  ...
# 4                              0         88.75  ...
# ..                           ...           ...  ...
# 235                            0        189.86  ...
# 236                            0        169.42  ...
# 237                            0        159.01  ...
# 238                            0        168.30  ...
# 239                            0        159.88  ...
#
#      Russian R @ Hopland (cfs; USGS)  Russian R @ Hopland (cfs; USGS) notes  \
# 0                             169.24                                      0
# 1                             168.95                                      0
# 2                             171.57                                      0
# 3                             172.65                                      0
# 4                             170.76                                      0
# ..                               ...                                    ...
# 235                           342.15                                      0
# 236                           334.62                                      0
# 237                           329.67                                      0
# 238                           324.76                                      0
# 239                           315.73                                      0
#
#      Precip @ Dam (in; 670 ft)  Precip @ Dam (in; 670 ft) notes  Basin Precip  \
# 0                          0.0                                0             -
# 1                          0.0                                0             -
# 2                          0.0                                0             -
# 3                          0.0                                0             -
# 4                          0.0                                0             -
# ..                         ...                              ...           ...
# 235                        0.0                                0             -
# 236                        0.0                                0             -
# 237                        0.0                                0             -
# 238                        0.0                                0             -
# 239                        0.0                                0             -
#
#      Basin Precip notes  Gross Pool Gross Pool(elev) Russian R nr Ukiah (cfs)  \
# 0                     -           -                -                     0.02
# 1                     -      116470            764.8                     0.02
# 2                     -      116470            764.8                     0.02
# 3                     -      116470            764.8                     0.02
# 4                     -      116470            764.8                     0.02
# ..                  ...         ...              ...                      ...
# 235                   -      116470            764.8                    65.04
# 236                   -      116470            764.8                    62.23
# 237                   -      116470            764.8                    58.76
# 238                   -      116470            764.8                    56.14
# 239                   -      116470            764.8                    56.63
#
#     Russian R nr Ukiah (cfs) notes
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ..                             ...
# 235                              0
# 236                              0
# 237                              0
# 238                              0
# 239                              0
#
# [240 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# ISO 8601 Date Time                        0
# Top of Conservation High (ac-ft)          0
# Top of Conservation High (ac-ft) notes    0
# Top of Conservation (ac-ft)               0
# Top of Conservation (ac-ft) notes         0
# Storage (ac-ft)                           0
# Storage (ac-ft) notes                     0
# Elevation (ft-NGVD29)                     0
# Elevation (ft-NGVD29) notes               0
# Inflow (cfs)                              0
# Inflow (cfs) notes                        0
# Outflow (cfs; 614 ft)                     0
# Outflow (cfs; 614 ft) notes               0
# Russian R @ Hopland (cfs; USGS)           0
# Russian R @ Hopland (cfs; USGS) notes     0
# Precip @ Dam (in; 670 ft)                 0
# Precip @ Dam (in; 670 ft) notes           0
# Basin Precip                              0
# Basin Precip notes                        0
# Gross Pool                                0
# Gross Pool(elev)                          0
# Russian R nr Ukiah (cfs)                  0
# Russian R nr Ukiah (cfs) notes            0
# dtype: int64

# %% [markdown]
# Based on this `.isna()` check, it appears this dataset has no null values. However, if we take a close look at the data. There are clearly some missing values. This dataset uses `-` in spaces that should be nulls. Some other columns use `0` where there should be nulls.

# %% [markdown]
# **Step 1:** Convert missing values to nulls.

# %%
# Replace dashes with nans
df[df=='-'] = np.nan
df
# Out:
#             ISO 8601 Date Time Top of Conservation High (ac-ft)  \
# 0    2023-08-30T24:00:00-07:00                           111000
# 1    2023-08-31T24:00:00-07:00                           111000
# 2    2023-09-01T24:00:00-07:00                           111000
# 3    2023-09-02T24:00:00-07:00                           111000
# 4    2023-09-03T24:00:00-07:00                           111000
# ..                         ...                              ...
# 235  2024-04-21T24:00:00-07:00                            99930
# 236  2024-04-22T24:00:00-07:00                           100545
# 237  2024-04-23T24:00:00-07:00                           101160
# 238  2024-04-24T24:00:00-07:00                           101775
# 239  2024-04-25T24:00:00-07:00                           102390
#
#      Top of Conservation High (ac-ft) notes Top of Conservation (ac-ft)  \
# 0                                         0                       86400
# 1                                         0                       86400
# 2                                         0                       86400
# 3                                         0                       86400
# 4                                         0                       86400
# ..                                      ...                         ...
# 235                                       0                       86400
# 236                                       0                       86400
# 237                                       0                       86400
# 238                                       0                       86400
# 239                                       0                       86400
#
#      Top of Conservation (ac-ft) notes  Storage (ac-ft)  \
# 0                                    0            84192
# 1                                    0            83966
# 2                                    0            83723
# 3                                    0            83480
# 4                                    0            83271
# ..                                 ...              ...
# 235                                  0           100431
# 236                                  0           100449
# 237                                  0           100467
# 238                                  0           100485
# 239                                  0           100503
#
#      Storage (ac-ft) notes  Elevation (ft-NGVD29)  \
# 0                        0                 746.75
# 1                        0                 746.62
# 2                        0                 746.48
# 3                        0                 746.34
# 4                        0                 746.22
# ..                     ...                    ...
# 235                      0                 755.96
# 236                      0                 755.97
# 237                      0                 755.98
# 238                      0                 755.99
# 239                      0                 756.00
#
#      Elevation (ft-NGVD29) notes  Inflow (cfs)  ...  \
# 0                              0         80.54  ...
# 1                              0         92.30  ...
# 2                              0         74.82  ...
# 3                              0         76.72  ...
# 4                              0         88.75  ...
# ..                           ...           ...  ...
# 235                            0        189.86  ...
# 236                            0        169.42  ...
# 237                            0        159.01  ...
# 238                            0        168.30  ...
# 239                            0        159.88  ...
#
#      Russian R @ Hopland (cfs; USGS)  Russian R @ Hopland (cfs; USGS) notes  \
# 0                             169.24                                      0
# 1                             168.95                                      0
# 2                             171.57                                      0
# 3                             172.65                                      0
# 4                             170.76                                      0
# ..                               ...                                    ...
# 235                           342.15                                      0
# 236                           334.62                                      0
# 237                           329.67                                      0
# 238                           324.76                                      0
# 239                           315.73                                      0
#
#      Precip @ Dam (in; 670 ft)  Precip @ Dam (in; 670 ft) notes  Basin Precip  \
# 0                          0.0                                0           NaN
# 1                          0.0                                0           NaN
# 2                          0.0                                0           NaN
# 3                          0.0                                0           NaN
# 4                          0.0                                0           NaN
# ..                         ...                              ...           ...
# 235                        0.0                                0           NaN
# 236                        0.0                                0           NaN
# 237                        0.0                                0           NaN
# 238                        0.0                                0           NaN
# 239                        0.0                                0           NaN
#
#      Basin Precip notes  Gross Pool Gross Pool(elev) Russian R nr Ukiah (cfs)  \
# 0                   NaN         NaN              NaN                     0.02
# 1                   NaN      116470            764.8                     0.02
# 2                   NaN      116470            764.8                     0.02
# 3                   NaN      116470            764.8                     0.02
# 4                   NaN      116470            764.8                     0.02
# ..                  ...         ...              ...                      ...
# 235                 NaN      116470            764.8                    65.04
# 236                 NaN      116470            764.8                    62.23
# 237                 NaN      116470            764.8                    58.76
# 238                 NaN      116470            764.8                    56.14
# 239                 NaN      116470            764.8                    56.63
#
#     Russian R nr Ukiah (cfs) notes
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ..                             ...
# 235                              0
# 236                              0
# 237                              0
# 238                              0
# 239                              0
#
# [240 rows x 23 columns]

# %%
# Use .info to check on the zeros
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ISO 8601 Date Time                      240 non-null    object
#  1   Top of Conservation High (ac-ft)        239 non-null    object
#  2   Top of Conservation High (ac-ft) notes  240 non-null    int64
#  3   Top of Conservation (ac-ft)             239 non-null    object
#  4   Top of Conservation (ac-ft) notes       240 non-null    int64
#  5   Storage (ac-ft)                         240 non-null    int64
#  6   Storage (ac-ft) notes                   240 non-null    int64
#  7   Elevation (ft-NGVD29)                   240 non-null    float64
#  8   Elevation (ft-NGVD29) notes             240 non-null    int64
#  9   Inflow (cfs)                            240 non-null    float64
#  10  Inflow (cfs) notes                      240 non-null    int64
#  11  Outflow (cfs; 614 ft)                   240 non-null    float64
#  12  Outflow (cfs; 614 ft) notes             240 non-null    int64
#  13  Russian R @ Hopland (cfs; USGS)         240 non-null    float64
#  14  Russian R @ Hopland (cfs; USGS) notes   240 non-null    int64
#  15  Precip @ Dam (in; 670 ft)               240 non-null    float64
#  16  Precip @ Dam (in; 670 ft) notes         240 non-null    int64
#  17  Basin Precip                            0 non-null      object
#  18  Basin Precip notes                      0 non-null      object
#  19  Gross Pool                              239 non-null    object
#  20  Gross Pool(elev)                        239 non-null    object
#  21  Russian R nr Ukiah (cfs)                240 non-null    float64
#  22  Russian R nr Ukiah (cfs) notes          240 non-null    int64
# dtypes: float64(6), int64(10), object(7)
# memory usage: 43.3+ KB

# %% [markdown]
# They are type int.

# %%
# Replace 0 with nan in columns where the column name contains the word "notes"
notes_columns = [col for col in df.columns if 'notes' in col]
df[notes_columns] = df[notes_columns].replace(0, np.nan)
df
# Out:
#             ISO 8601 Date Time Top of Conservation High (ac-ft)  \
# 0    2023-08-30T24:00:00-07:00                           111000
# 1    2023-08-31T24:00:00-07:00                           111000
# 2    2023-09-01T24:00:00-07:00                           111000
# 3    2023-09-02T24:00:00-07:00                           111000
# 4    2023-09-03T24:00:00-07:00                           111000
# ..                         ...                              ...
# 235  2024-04-21T24:00:00-07:00                            99930
# 236  2024-04-22T24:00:00-07:00                           100545
# 237  2024-04-23T24:00:00-07:00                           101160
# 238  2024-04-24T24:00:00-07:00                           101775
# 239  2024-04-25T24:00:00-07:00                           102390
#
#      Top of Conservation High (ac-ft) notes Top of Conservation (ac-ft)  \
# 0                                       NaN                       86400
# 1                                       NaN                       86400
# 2                                       NaN                       86400
# 3                                       NaN                       86400
# 4                                       NaN                       86400
# ..                                      ...                         ...
# 235                                     NaN                       86400
# 236                                     NaN                       86400
# 237                                     NaN                       86400
# 238                                     NaN                       86400
# 239                                     NaN                       86400
#
#      Top of Conservation (ac-ft) notes  Storage (ac-ft)  \
# 0                                  NaN            84192
# 1                                  NaN            83966
# 2                                  NaN            83723
# 3                                  NaN            83480
# 4                                  NaN            83271
# ..                                 ...              ...
# 235                                NaN           100431
# 236                                NaN           100449
# 237                                NaN           100467
# 238                                NaN           100485
# 239                                NaN           100503
#
#      Storage (ac-ft) notes  Elevation (ft-NGVD29)  \
# 0                      NaN                 746.75
# 1                      NaN                 746.62
# 2                      NaN                 746.48
# 3                      NaN                 746.34
# 4                      NaN                 746.22
# ..                     ...                    ...
# 235                    NaN                 755.96
# 236                    NaN                 755.97
# 237                    NaN                 755.98
# 238                    NaN                 755.99
# 239                    NaN                 756.00
#
#      Elevation (ft-NGVD29) notes  Inflow (cfs)  ...  \
# 0                            NaN         80.54  ...
# 1                            NaN         92.30  ...
# 2                            NaN         74.82  ...
# 3                            NaN         76.72  ...
# 4                            NaN         88.75  ...
# ..                           ...           ...  ...
# 235                          NaN        189.86  ...
# 236                          NaN        169.42  ...
# 237                          NaN        159.01  ...
# 238                          NaN        168.30  ...
# 239                          NaN        159.88  ...
#
#      Russian R @ Hopland (cfs; USGS)  Russian R @ Hopland (cfs; USGS) notes  \
# 0                             169.24                                    NaN
# 1                             168.95                                    NaN
# 2                             171.57                                    NaN
# 3                             172.65                                    NaN
# 4                             170.76                                    NaN
# ..                               ...                                    ...
# 235                           342.15                                    NaN
# 236                           334.62                                    NaN
# 237                           329.67                                    NaN
# 238                           324.76                                    NaN
# 239                           315.73                                    NaN
#
#      Precip @ Dam (in; 670 ft)  Precip @ Dam (in; 670 ft) notes  Basin Precip  \
# 0                          0.0                              NaN           NaN
# 1                          0.0                              NaN           NaN
# 2                          0.0                              NaN           NaN
# 3                          0.0                              NaN           NaN
# 4                          0.0                              NaN           NaN
# ..                         ...                              ...           ...
# 235                        0.0                              NaN           NaN
# 236                        0.0                              NaN           NaN
# 237                        0.0                              NaN           NaN
# 238                        0.0                              NaN           NaN
# 239                        0.0                              NaN           NaN
#
#      Basin Precip notes  Gross Pool Gross Pool(elev) Russian R nr Ukiah (cfs)  \
# 0                   NaN         NaN              NaN                     0.02
# 1                   NaN      116470            764.8                     0.02
# 2                   NaN      116470            764.8                     0.02
# 3                   NaN      116470            764.8                     0.02
# 4                   NaN      116470            764.8                     0.02
# ..                  ...         ...              ...                      ...
# 235                 NaN      116470            764.8                    65.04
# 236                 NaN      116470            764.8                    62.23
# 237                 NaN      116470            764.8                    58.76
# 238                 NaN      116470            764.8                    56.14
# 239                 NaN      116470            764.8                    56.63
#
#     Russian R nr Ukiah (cfs) notes
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 235                            NaN
# 236                            NaN
# 237                            NaN
# 238                            NaN
# 239                            NaN
#
# [240 rows x 23 columns]

# %% [markdown]
# **Step 2** Analyze type and amount of missing data.

# %%
df.isna().sum()
# Out:
# ISO 8601 Date Time                          0
# Top of Conservation High (ac-ft)            1
# Top of Conservation High (ac-ft) notes    239
# Top of Conservation (ac-ft)                 1
# Top of Conservation (ac-ft) notes         239
# Storage (ac-ft)                             0
# Storage (ac-ft) notes                     240
# Elevation (ft-NGVD29)                       0
# Elevation (ft-NGVD29) notes               240
# Inflow (cfs)                                0
# Inflow (cfs) notes                        240
# Outflow (cfs; 614 ft)                       0
# Outflow (cfs; 614 ft) notes               240
# Russian R @ Hopland (cfs; USGS)             0
# Russian R @ Hopland (cfs; USGS) notes     240
# Precip @ Dam (in; 670 ft)                   0
# Precip @ Dam (in; 670 ft) notes           240
# Basin Precip                              240
# Basin Precip notes                        240
# Gross Pool                                  1
# Gross Pool(elev)                            1
# Russian R nr Ukiah (cfs)                    0
# Russian R nr Ukiah (cfs) notes            240
# dtype: int64

# %% [markdown]
# Some of of these columns have all almonst all missing data. These tend to be ones with "notes" in their column name. Maybe those columns are occasionally filled in during abnormal situations, but usually don't have entries. Some of the other columns have one missing data point. We'll treat the columns with many missing and columns with a few missing differently.

# %% [markdown]
# **Step 3:** Decide on an approach.
# Some of of these columns have a lot of missing data. Let's drop those. Others can be imputed.

# %%
# drop columns (axis = 1) that have more than 230 nan values (thresh = 230)
df_dropped = df.dropna(axis = 1, thresh = 230)
df_dropped
# Out:
#             ISO 8601 Date Time Top of Conservation High (ac-ft)  \
# 0    2023-08-30T24:00:00-07:00                           111000
# 1    2023-08-31T24:00:00-07:00                           111000
# 2    2023-09-01T24:00:00-07:00                           111000
# 3    2023-09-02T24:00:00-07:00                           111000
# 4    2023-09-03T24:00:00-07:00                           111000
# ..                         ...                              ...
# 235  2024-04-21T24:00:00-07:00                            99930
# 236  2024-04-22T24:00:00-07:00                           100545
# 237  2024-04-23T24:00:00-07:00                           101160
# 238  2024-04-24T24:00:00-07:00                           101775
# 239  2024-04-25T24:00:00-07:00                           102390
#
#     Top of Conservation (ac-ft)  Storage (ac-ft)  Elevation (ft-NGVD29)  \
# 0                         86400            84192                 746.75
# 1                         86400            83966                 746.62
# 2                         86400            83723                 746.48
# 3                         86400            83480                 746.34
# 4                         86400            83271                 746.22
# ..                          ...              ...                    ...
# 235                       86400           100431                 755.96
# 236                       86400           100449                 755.97
# 237                       86400           100467                 755.98
# 238                       86400           100485                 755.99
# 239                       86400           100503                 756.00
#
#      Inflow (cfs)  Outflow (cfs; 614 ft)  Russian R @ Hopland (cfs; USGS)  \
# 0           80.54                 189.00                           169.24
# 1           92.30                 189.00                           168.95
# 2           74.82                 189.00                           171.57
# 3           76.72                 189.00                           172.65
# 4           88.75                 181.94                           170.76
# ..            ...                    ...                              ...
# 235        189.86                 150.91                           342.15
# 236        169.42                 148.02                           334.62
# 237        159.01                 142.60                           329.67
# 238        168.30                 151.00                           324.76
# 239        159.88                 143.95                           315.73
#
#      Precip @ Dam (in; 670 ft) Gross Pool Gross Pool(elev)  \
# 0                          0.0        NaN              NaN
# 1                          0.0     116470            764.8
# 2                          0.0     116470            764.8
# 3                          0.0     116470            764.8
# 4                          0.0     116470            764.8
# ..                         ...        ...              ...
# 235                        0.0     116470            764.8
# 236                        0.0     116470            764.8
# 237                        0.0     116470            764.8
# 238                        0.0     116470            764.8
# 239                        0.0     116470            764.8
#
#      Russian R nr Ukiah (cfs)
# 0                        0.02
# 1                        0.02
# 2                        0.02
# 3                        0.02
# 4                        0.02
# ..                        ...
# 235                     65.04
# 236                     62.23
# 237                     58.76
# 238                     56.14
# 239                     56.63
#
# [240 rows x 12 columns]

# %%
df_dropped.isna().sum()
# Out:
# ISO 8601 Date Time                  0
# Top of Conservation High (ac-ft)    1
# Top of Conservation (ac-ft)         1
# Storage (ac-ft)                     0
# Elevation (ft-NGVD29)               0
# Inflow (cfs)                        0
# Outflow (cfs; 614 ft)               0
# Russian R @ Hopland (cfs; USGS)     0
# Precip @ Dam (in; 670 ft)           0
# Gross Pool                          1
# Gross Pool(elev)                    1
# Russian R nr Ukiah (cfs)            0
# dtype: int64

# %% [markdown]
# Now we just have 4 columns with a missing value. We could drop those, but that isn't great for time series data. We don't want a gap in our time series (this can be problematic for many time series methods, so lets try to fill in the gaps (impute) instead. Let's first check on the distributions.

# %%
# convert types before plotting distributions
df_dropped = df_dropped.assign(cons_high = df['Top of Conservation High (ac-ft)'].astype(float),
              cons = df['Top of Conservation (ac-ft)'].astype(float),
              gross_pool = df['Gross Pool'].astype(float),
              gross_pool_elev = df['Gross Pool(elev)'].astype(float))

df_dropped.drop(columns = ['Top of Conservation High (ac-ft)', 'Top of Conservation (ac-ft)','Gross Pool','Gross Pool(elev)'],inplace=True)
df_dropped
# Out:
#             ISO 8601 Date Time  Storage (ac-ft)  Elevation (ft-NGVD29)  \
# 0    2023-08-30T24:00:00-07:00            84192                 746.75
# 1    2023-08-31T24:00:00-07:00            83966                 746.62
# 2    2023-09-01T24:00:00-07:00            83723                 746.48
# 3    2023-09-02T24:00:00-07:00            83480                 746.34
# 4    2023-09-03T24:00:00-07:00            83271                 746.22
# ..                         ...              ...                    ...
# 235  2024-04-21T24:00:00-07:00           100431                 755.96
# 236  2024-04-22T24:00:00-07:00           100449                 755.97
# 237  2024-04-23T24:00:00-07:00           100467                 755.98
# 238  2024-04-24T24:00:00-07:00           100485                 755.99
# 239  2024-04-25T24:00:00-07:00           100503                 756.00
#
#      Inflow (cfs)  Outflow (cfs; 614 ft)  Russian R @ Hopland (cfs; USGS)  \
# 0           80.54                 189.00                           169.24
# 1           92.30                 189.00                           168.95
# 2           74.82                 189.00                           171.57
# 3           76.72                 189.00                           172.65
# 4           88.75                 181.94                           170.76
# ..            ...                    ...                              ...
# 235        189.86                 150.91                           342.15
# 236        169.42                 148.02                           334.62
# 237        159.01                 142.60                           329.67
# 238        168.30                 151.00                           324.76
# 239        159.88                 143.95                           315.73
#
#      Precip @ Dam (in; 670 ft)  Russian R nr Ukiah (cfs)  cons_high     cons  \
# 0                          0.0                      0.02   111000.0  86400.0
# 1                          0.0                      0.02   111000.0  86400.0
# 2                          0.0                      0.02   111000.0  86400.0
# 3                          0.0                      0.02   111000.0  86400.0
# 4                          0.0                      0.02   111000.0  86400.0
# ..                         ...                       ...        ...      ...
# 235                        0.0                     65.04    99930.0  86400.0
# 236                        0.0                     62.23   100545.0  86400.0
# 237                        0.0                     58.76   101160.0  86400.0
# 238                        0.0                     56.14   101775.0  86400.0
# 239                        0.0                     56.63   102390.0  86400.0
#
#      gross_pool  gross_pool_elev
# 0           NaN              NaN
# 1      116470.0            764.8
# 2      116470.0            764.8
# 3      116470.0            764.8
# 4      116470.0            764.8
# ..          ...              ...
# 235    116470.0            764.8
# 236    116470.0            764.8
# 237    116470.0            764.8
# 238    116470.0            764.8
# 239    116470.0            764.8
#
# [240 rows x 12 columns]

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ISO 8601 Date Time               240 non-null    object
#  1   Storage (ac-ft)                  240 non-null    int64
#  2   Elevation (ft-NGVD29)            240 non-null    float64
#  3   Inflow (cfs)                     240 non-null    float64
#  4   Outflow (cfs; 614 ft)            240 non-null    float64
#  5   Russian R @ Hopland (cfs; USGS)  240 non-null    float64
#  6   Precip @ Dam (in; 670 ft)        240 non-null    float64
#  7   Russian R nr Ukiah (cfs)         240 non-null    float64
#  8   cons_high                        239 non-null    float64
#  9   cons                             239 non-null    float64
#  10  gross_pool                       239 non-null    float64
#  11  gross_pool_elev                  239 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 22.6+ KB

# %%
# check distribution to decide how to impute
df_dropped.cons_high.hist();

# %%
# check distribution to decide how to impute
df_dropped.cons.hist();

# %%
# check distribution to decide how to impute
df_dropped.gross_pool.hist();

# %%
# check distribution to decide how to impute
df_dropped.gross_pool_elev.hist();

# %%
# Mean impute
gross_mean = df_dropped.gross_pool.mean()
df_dropped['gross_pool'].fillna(gross_mean,inplace=True)
df_dropped
# Out:
#             ISO 8601 Date Time  Storage (ac-ft)  Elevation (ft-NGVD29)  \
# 0    2023-08-30T24:00:00-07:00            84192                 746.75
# 1    2023-08-31T24:00:00-07:00            83966                 746.62
# 2    2023-09-01T24:00:00-07:00            83723                 746.48
# 3    2023-09-02T24:00:00-07:00            83480                 746.34
# 4    2023-09-03T24:00:00-07:00            83271                 746.22
# ..                         ...              ...                    ...
# 235  2024-04-21T24:00:00-07:00           100431                 755.96
# 236  2024-04-22T24:00:00-07:00           100449                 755.97
# 237  2024-04-23T24:00:00-07:00           100467                 755.98
# 238  2024-04-24T24:00:00-07:00           100485                 755.99
# 239  2024-04-25T24:00:00-07:00           100503                 756.00
#
#      Inflow (cfs)  Outflow (cfs; 614 ft)  Russian R @ Hopland (cfs; USGS)  \
# 0           80.54                 189.00                           169.24
# 1           92.30                 189.00                           168.95
# 2           74.82                 189.00                           171.57
# 3           76.72                 189.00                           172.65
# 4           88.75                 181.94                           170.76
# ..            ...                    ...                              ...
# 235        189.86                 150.91                           342.15
# 236        169.42                 148.02                           334.62
# 237        159.01                 142.60                           329.67
# 238        168.30                 151.00                           324.76
# 239        159.88                 143.95                           315.73
#
#      Precip @ Dam (in; 670 ft)  Russian R nr Ukiah (cfs)  cons_high     cons  \
# 0                          0.0                      0.02   111000.0  86400.0
# 1                          0.0                      0.02   111000.0  86400.0
# 2                          0.0                      0.02   111000.0  86400.0
# 3                          0.0                      0.02   111000.0  86400.0
# 4                          0.0                      0.02   111000.0  86400.0
# ..                         ...                       ...        ...      ...
# 235                        0.0                     65.04    99930.0  86400.0
# 236                        0.0                     62.23   100545.0  86400.0
# 237                        0.0                     58.76   101160.0  86400.0
# 238                        0.0                     56.14   101775.0  86400.0
# 239                        0.0                     56.63   102390.0  86400.0
#
#      gross_pool  gross_pool_elev
# 0      116470.0              NaN
# 1      116470.0            764.8
# 2      116470.0            764.8
# 3      116470.0            764.8
# 4      116470.0            764.8
# ..          ...              ...
# 235    116470.0            764.8
# 236    116470.0            764.8
# 237    116470.0            764.8
# 238    116470.0            764.8
# 239    116470.0            764.8
#
# [240 rows x 12 columns]

# %%
# Mean impute
gross_mean_elev = df_dropped.gross_pool_elev.mean()
df_dropped['gross_pool_elev'].fillna(gross_mean_elev,inplace=True)
df_dropped
# Out:
#             ISO 8601 Date Time  Storage (ac-ft)  Elevation (ft-NGVD29)  \
# 0    2023-08-30T24:00:00-07:00            84192                 746.75
# 1    2023-08-31T24:00:00-07:00            83966                 746.62
# 2    2023-09-01T24:00:00-07:00            83723                 746.48
# 3    2023-09-02T24:00:00-07:00            83480                 746.34
# 4    2023-09-03T24:00:00-07:00            83271                 746.22
# ..                         ...              ...                    ...
# 235  2024-04-21T24:00:00-07:00           100431                 755.96
# 236  2024-04-22T24:00:00-07:00           100449                 755.97
# 237  2024-04-23T24:00:00-07:00           100467                 755.98
# 238  2024-04-24T24:00:00-07:00           100485                 755.99
# 239  2024-04-25T24:00:00-07:00           100503                 756.00
#
#      Inflow (cfs)  Outflow (cfs; 614 ft)  Russian R @ Hopland (cfs; USGS)  \
# 0           80.54                 189.00                           169.24
# 1           92.30                 189.00                           168.95
# 2           74.82                 189.00                           171.57
# 3           76.72                 189.00                           172.65
# 4           88.75                 181.94                           170.76
# ..            ...                    ...                              ...
# 235        189.86                 150.91                           342.15
# 236        169.42                 148.02                           334.62
# 237        159.01                 142.60                           329.67
# 238        168.30                 151.00                           324.76
# 239        159.88                 143.95                           315.73
#
#      Precip @ Dam (in; 670 ft)  Russian R nr Ukiah (cfs)  cons_high     cons  \
# 0                          0.0                      0.02   111000.0  86400.0
# 1                          0.0                      0.02   111000.0  86400.0
# 2                          0.0                      0.02   111000.0  86400.0
# 3                          0.0                      0.02   111000.0  86400.0
# 4                          0.0                      0.02   111000.0  86400.0
# ..                         ...                       ...        ...      ...
# 235                        0.0                     65.04    99930.0  86400.0
# 236                        0.0                     62.23   100545.0  86400.0
# 237                        0.0                     58.76   101160.0  86400.0
# 238                        0.0                     56.14   101775.0  86400.0
# 239                        0.0                     56.63   102390.0  86400.0
#
#      gross_pool  gross_pool_elev
# 0      116470.0            764.8
# 1      116470.0            764.8
# 2      116470.0            764.8
# 3      116470.0            764.8
# 4      116470.0            764.8
# ..          ...              ...
# 235    116470.0            764.8
# 236    116470.0            764.8
# 237    116470.0            764.8
# 238    116470.0            764.8
# 239    116470.0            764.8
#
# [240 rows x 12 columns]

# %%
df_dropped[df_dropped.cons.isna()]
# Out:
#             ISO 8601 Date Time  Storage (ac-ft)  Elevation (ft-NGVD29)  \
# 230  2024-04-16T24:00:00-07:00           100003                 755.72
#
#      Inflow (cfs)  Outflow (cfs; 614 ft)  Russian R @ Hopland (cfs; USGS)  \
# 230        229.32                 128.97                           394.97
#
#      Precip @ Dam (in; 670 ft)  Russian R nr Ukiah (cfs)  cons_high  cons  \
# 230                        0.0                     99.15        NaN   NaN
#
#      gross_pool  gross_pool_elev
# 230    116470.0            764.8

# %%
# Mode impute
cons_high_mode = df_dropped.cons_high.mode().values[0]
df_dropped['cons_high'].fillna(cons_high_mode,inplace=True)
cons_mode = df_dropped.cons.mode().values[0]
df_dropped['cons'].fillna(cons_mode,inplace=True)

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ISO 8601 Date Time               240 non-null    object
#  1   Storage (ac-ft)                  240 non-null    int64
#  2   Elevation (ft-NGVD29)            240 non-null    float64
#  3   Inflow (cfs)                     240 non-null    float64
#  4   Outflow (cfs; 614 ft)            240 non-null    float64
#  5   Russian R @ Hopland (cfs; USGS)  240 non-null    float64
#  6   Precip @ Dam (in; 670 ft)        240 non-null    float64
#  7   Russian R nr Ukiah (cfs)         240 non-null    float64
#  8   cons_high                        240 non-null    float64
#  9   cons                             240 non-null    float64
#  10  gross_pool                       240 non-null    float64
#  11  gross_pool_elev                  240 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 22.6+ KB

# %% [markdown]
# No more missing values!
# **Step 4: Evaluate and compare**
# Let's try plotting through time to get a complete time series.

# %%
df_dropped['date'] = pd.to_datetime(df_dropped['ISO 8601 Date Time'].str[:10])

# %%
import seaborn as sns

sns.lineplot(data = df_dropped, x = 'date',y = 'cons');

# %% [markdown]
# Wait! This graph looks strange. It looks like the point we filled in is way different than what we might expect... Maybe a mode impute was *NOT* the right choice. It could have been better to use the points close in time to approximate our missing value. We will learn how to do that and other techniques in the next lecture.
